# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Import the requests library.
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ccecc8ad1d8ab6868bb0beb01093a3ac

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather ["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description,
                          "Date": city_date})
                            
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | artyom
# Processing Record 4 of Set 1 | vao
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | maridi
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | victoria
# Processing Record 10 of Set 1 | frasinet
# Processing Record 11 of Set 1 | riviere-au-renard
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | berezovyy
# Processing Record 14 of Set 1 | norman wells
# Processing Record 15 of Set 1 | ponta do sol
# Processing Record 16 of Set 1 | san quintin
# Processing Record 17 of Set 1 | meulaboh
# Processing Record 18 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | denpasar
# Processing Record 21 of Set 1 | zolotukhino
# Processing Record 22 of Set 1 | pavilosta
# Processing Record 23 of Set 1 | ancud
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | salalah
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | inhambane
# Processing Record 34 of Set 1 | kenora
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | garmsar
# Processing Record 37 of Set 1 | vila
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | trelew
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | namibe
# Processing Record 42 of Set 1 | richards bay
# Processing Record 43 of Set 1 | leningradskiy
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | esperance
# Processing Record 46 of Set 1 | menongue
# Processing Record 47 of Set 1 | raudeberg
# Processing Record 48 of Set 1 | bambous virieux
# Processing Record 49 of Set 1 | juifang
# City not found. Skipping...
# Processing Record 50 of Set 1 | birin
# Processing Record 1 of Set 2 | douglas
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | ponta delgada
# Processing Record 4 of Set 2 | yurkivka
# Processing Record 5 of Set 2 | aosta
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | luis correia
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | doha
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 2 | asau
# Processing Record 13 of Set 2 | marsh harbour
# Processing Record 14 of Set 2 | mao
# Processing Record 15 of Set 2 | mogadishu
# Processing Record 16 of Set 2 | la ronge
# Processing Record 17 of Set 2 | geraldton
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | hatillo
# Processing Record 20 of Set 2 | preston
# Processing Record 21 of Set 2 | ushuaia
# Processing Record 22 of Set 2 | nyurba
# Processing Record 23 of Set 2 | zhangye
# Processing Record 24 of Set 2 | dzhalka
# Processing Record 25 of Set 2 | mount isa
# Processing Record 26 of Set 2 | sagua de tanamo
# Processing Record 27 of Set 2 | itacarambi
# Processing Record 28 of Set 2 | lillooet
# Processing Record 29 of Set 2 | guerrero negro
# Processing Record 30 of Set 2 | beringovskiy
# Processing Record 31 of Set 2 | surt
# Processing Record 32 of Set 2 | novyy urgal
# Processing Record 33 of Set 2 | guekedou
# City not found. Skipping...
# Processing Record 34 of Set 2 | muros
# Processing Record 35 of Set 2 | busselton
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | bathsheba
# Processing Record 38 of Set 2 | lorengau
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | yerbogachen
# Processing Record 41 of Set 2 | auki
# Processing Record 42 of Set 2 | ptuj
# Processing Record 43 of Set 2 | tostamaa
# City not found. Skipping...
# Processing Record 44 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 2 | half moon bay
# Processing Record 46 of Set 2 | yatou
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | yellowknife
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | saint-joseph
# Processing Record 1 of Set 3 | jishou
# Processing Record 2 of Set 3 | bludenz
# Processing Record 3 of Set 3 | we
# City not found. Skipping...
# Processing Record 4 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 3 | higuey
# City not found. Skipping...
# Processing Record 6 of Set 3 | kahului
# Processing Record 7 of Set 3 | paamiut
# Processing Record 8 of Set 3 | luanda
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 3 | avarua
# Processing Record 12 of Set 3 | puerto parra
# Processing Record 13 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 3 | namatanai
# Processing Record 15 of Set 3 | albion
# Processing Record 16 of Set 3 | katsuura
# Processing Record 17 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 3 | bonthe
# Processing Record 19 of Set 3 | betong
# Processing Record 20 of Set 3 | athabasca
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | pisco
# Processing Record 23 of Set 3 | konevo
# Processing Record 24 of Set 3 | tank
# Processing Record 25 of Set 3 | namakkal
# Processing Record 26 of Set 3 | isangel
# Processing Record 27 of Set 3 | ayorou
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | pevek
# Processing Record 30 of Set 3 | hami
# Processing Record 31 of Set 3 | hithadhoo
# Processing Record 32 of Set 3 | bredasdorp
# Processing Record 33 of Set 3 | kuzino
# Processing Record 34 of Set 3 | kita
# Processing Record 35 of Set 3 | hofn
# Processing Record 36 of Set 3 | portland
# Processing Record 37 of Set 3 | aras
# Processing Record 38 of Set 3 | mahebourg
# Processing Record 39 of Set 3 | tiarei
# Processing Record 40 of Set 3 | broome
# Processing Record 41 of Set 3 | barcelos
# Processing Record 42 of Set 3 | kapaa
# Processing Record 43 of Set 3 | kaitangata
# Processing Record 44 of Set 3 | kurumkan
# Processing Record 45 of Set 3 | mataura
# Processing Record 46 of Set 3 | bubaque
# Processing Record 47 of Set 3 | bengkulu
# Processing Record 48 of Set 3 | anloga
# Processing Record 49 of Set 3 | barrow
# Processing Record 50 of Set 3 | airai
# Processing Record 1 of Set 4 | teknaf
# Processing Record 2 of Set 4 | uruzgan
# Processing Record 3 of Set 4 | yumen
# Processing Record 4 of Set 4 | new norfolk
# Processing Record 5 of Set 4 | pemangkat
# Processing Record 6 of Set 4 | vaini
# Processing Record 7 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 8 of Set 4 | chililabombwe
# Processing Record 9 of Set 4 | nhulunbuy
# Processing Record 10 of Set 4 | hilo
# Processing Record 11 of Set 4 | sunagawa
# Processing Record 12 of Set 4 | horsham
# Processing Record 13 of Set 4 | zagreb
# Processing Record 14 of Set 4 | angoche
# Processing Record 15 of Set 4 | comodoro rivadavia
# Processing Record 16 of Set 4 | viedma
# Processing Record 17 of Set 4 | dingle
# Processing Record 18 of Set 4 | grand-santi
# Processing Record 19 of Set 4 | mitu
# Processing Record 20 of Set 4 | coihaique
# Processing Record 21 of Set 4 | saldanha
# Processing Record 22 of Set 4 | flinders
# Processing Record 23 of Set 4 | tuatapere
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | maltahohe
# Processing Record 26 of Set 4 | kisangani
# Processing Record 27 of Set 4 | amot
# Processing Record 28 of Set 4 | bethel
# Processing Record 29 of Set 4 | iqaluit
# Processing Record 30 of Set 4 | corral nuevo
# Processing Record 31 of Set 4 | port shepstone
# Processing Record 32 of Set 4 | samarai
# Processing Record 33 of Set 4 | porto walter
# Processing Record 34 of Set 4 | margate
# Processing Record 35 of Set 4 | shenjiamen
# Processing Record 36 of Set 4 | camacha
# Processing Record 37 of Set 4 | valverde del camino
# Processing Record 38 of Set 4 | sitka
# Processing Record 39 of Set 4 | rahon
# Processing Record 40 of Set 4 | saint anthony
# Processing Record 41 of Set 4 | onguday
# Processing Record 42 of Set 4 | wattegama
# Processing Record 43 of Set 4 | lavrentiya
# Processing Record 44 of Set 4 | plettenberg bay
# Processing Record 45 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 47 of Set 4 | lazaro cardenas
# Processing Record 48 of Set 4 | poplar bluff
# Processing Record 49 of Set 4 | san pedro
# Processing Record 50 of Set 4 | caucaia
# Processing Record 1 of Set 5 | krasnoselkup
# Processing Record 2 of Set 5 | saskylakh
# Processing Record 3 of Set 5 | ocean city
# Processing Record 4 of Set 5 | clyde river
# Processing Record 5 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 6 of Set 5 | saint-francois
# Processing Record 7 of Set 5 | wahpeton
# Processing Record 8 of Set 5 | kashi
# Processing Record 9 of Set 5 | lebu
# Processing Record 10 of Set 5 | husavik
# Processing Record 11 of Set 5 | saint-philippe
# Processing Record 12 of Set 5 | bestobe
# Processing Record 13 of Set 5 | ames
# Processing Record 14 of Set 5 | antonina
# Processing Record 15 of Set 5 | aseri
# Processing Record 16 of Set 5 | gat
# Processing Record 17 of Set 5 | skelleftea
# Processing Record 18 of Set 5 | saint-ambroise
# Processing Record 19 of Set 5 | mahina
# Processing Record 20 of Set 5 | coquimbo
# Processing Record 21 of Set 5 | agirish
# Processing Record 22 of Set 5 | vardo
# Processing Record 23 of Set 5 | marsaxlokk
# Processing Record 24 of Set 5 | yarmouth
# Processing Record 25 of Set 5 | venustiano carranza
# Processing Record 26 of Set 5 | cap-aux-meules
# Processing Record 27 of Set 5 | ati
# Processing Record 28 of Set 5 | barroualie
# City not found. Skipping...
# Processing Record 29 of Set 5 | baft
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 5 | rokiskis
# Processing Record 33 of Set 5 | volokonovka
# Processing Record 34 of Set 5 | lasa
# Processing Record 35 of Set 5 | maniitsoq
# Processing Record 36 of Set 5 | broken hill
# Processing Record 37 of Set 5 | butaritari
# Processing Record 38 of Set 5 | sao miguel do araguaia
# Processing Record 39 of Set 5 | thompson
# Processing Record 40 of Set 5 | kodiak
# Processing Record 41 of Set 5 | mumford
# Processing Record 42 of Set 5 | pontes e lacerda
# Processing Record 43 of Set 5 | tiksi
# Processing Record 44 of Set 5 | anadyr
# Processing Record 45 of Set 5 | san carlos de bariloche
# Processing Record 46 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 47 of Set 5 | severo-kurilsk
# Processing Record 48 of Set 5 | nanortalik
# Processing Record 49 of Set 5 | pathein
# Processing Record 50 of Set 5 | tarija
# Processing Record 1 of Set 6 | aleksandrov gay
# Processing Record 2 of Set 6 | osakarovka
# Processing Record 3 of Set 6 | faanui
# Processing Record 4 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 6 | suleja
# Processing Record 6 of Set 6 | juneau
# Processing Record 7 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 6 | kibaek
# Processing Record 9 of Set 6 | hervey bay
# Processing Record 10 of Set 6 | lufilufi
# Processing Record 11 of Set 6 | los llanos de aridane
# Processing Record 12 of Set 6 | constantine
# Processing Record 13 of Set 6 | bandarbeyla
# Processing Record 14 of Set 6 | balingasay
# Processing Record 15 of Set 6 | gorzow wielkopolski
# Processing Record 16 of Set 6 | manzini
# Processing Record 17 of Set 6 | sarangani
# Processing Record 18 of Set 6 | dvinskoy
# Processing Record 19 of Set 6 | lata
# Processing Record 20 of Set 6 | korla
# Processing Record 21 of Set 6 | ubatuba
# Processing Record 22 of Set 6 | nelson bay
# Processing Record 23 of Set 6 | provideniya
# Processing Record 24 of Set 6 | vila franca do campo
# Processing Record 25 of Set 6 | bodhan
# Processing Record 26 of Set 6 | cayenne
# Processing Record 27 of Set 6 | longyearbyen
# Processing Record 28 of Set 6 | san roque
# Processing Record 29 of Set 6 | outjo
# Processing Record 30 of Set 6 | nome
# Processing Record 31 of Set 6 | hirara
# Processing Record 32 of Set 6 | sorong
# Processing Record 33 of Set 6 | sinnamary
# Processing Record 34 of Set 6 | port lincoln
# Processing Record 35 of Set 6 | cortes
# Processing Record 36 of Set 6 | portobelo
# Processing Record 37 of Set 6 | sorland
# Processing Record 38 of Set 6 | saint-nazaire
# Processing Record 39 of Set 6 | bombay
# Processing Record 40 of Set 6 | chuy
# Processing Record 41 of Set 6 | dawei
# Processing Record 42 of Set 6 | ziyang
# Processing Record 43 of Set 6 | sola
# Processing Record 44 of Set 6 | myaundzha
# Processing Record 45 of Set 6 | labuan
# Processing Record 46 of Set 6 | woodward
# Processing Record 47 of Set 6 | lishu
# Processing Record 48 of Set 6 | mananara
# Processing Record 49 of Set 6 | fort-shevchenko
# Processing Record 50 of Set 6 | kulu
# Processing Record 1 of Set 7 | mansehra
# Processing Record 2 of Set 7 | iralaya
# Processing Record 3 of Set 7 | grootfontein
# Processing Record 4 of Set 7 | sibolga
# Processing Record 5 of Set 7 | lephepe
# City not found. Skipping...
# Processing Record 6 of Set 7 | medea
# Processing Record 7 of Set 7 | amazar
# Processing Record 8 of Set 7 | svetlyy
# Processing Record 9 of Set 7 | morros
# Processing Record 10 of Set 7 | constitucion
# Processing Record 11 of Set 7 | thinadhoo
# Processing Record 12 of Set 7 | henties bay
# Processing Record 13 of Set 7 | tuktoyaktuk
# Processing Record 14 of Set 7 | chitipa
# Processing Record 15 of Set 7 | sechura
# Processing Record 16 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 7 | banda aceh
# Processing Record 18 of Set 7 | srandakan
# Processing Record 19 of Set 7 | okhotsk
# Processing Record 20 of Set 7 | phalaborwa
# Processing Record 21 of Set 7 | ardakan
# Processing Record 22 of Set 7 | atbasar
# Processing Record 23 of Set 7 | kavieng
# Processing Record 24 of Set 7 | lagoa
# Processing Record 25 of Set 7 | saint-georges
# Processing Record 26 of Set 7 | sciacca
# Processing Record 27 of Set 7 | ardee
# Processing Record 28 of Set 7 | lemesos
# City not found. Skipping...
# Processing Record 29 of Set 7 | saint-louis
# Processing Record 30 of Set 7 | belaya gora
# Processing Record 31 of Set 7 | kyaikkami
# Processing Record 32 of Set 7 | kulhudhuffushi
# Processing Record 33 of Set 7 | pocatello
# Processing Record 34 of Set 7 | sitangkai
# Processing Record 35 of Set 7 | skibbereen
# Processing Record 36 of Set 7 | cabo san lucas
# Processing Record 37 of Set 7 | praia da vitoria
# Processing Record 38 of Set 7 | fukue
# Processing Record 39 of Set 7 | dhidhdhoo
# Processing Record 40 of Set 7 | brae
# Processing Record 41 of Set 7 | beidao
# Processing Record 42 of Set 7 | cidreira
# Processing Record 43 of Set 7 | kaeo
# Processing Record 44 of Set 7 | ribeira grande
# Processing Record 45 of Set 7 | hambantota
# Processing Record 46 of Set 7 | paragominas
# Processing Record 47 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 7 | susanville
# Processing Record 49 of Set 7 | teberda
# Processing Record 50 of Set 7 | nisia floresta
# Processing Record 1 of Set 8 | port arthur
# Processing Record 2 of Set 8 | castro
# Processing Record 3 of Set 8 | kruisfontein
# Processing Record 4 of Set 8 | vila do maio
# Processing Record 5 of Set 8 | torbay
# Processing Record 6 of Set 8 | saint george
# Processing Record 7 of Set 8 | lompoc
# Processing Record 8 of Set 8 | komsomolskiy
# Processing Record 9 of Set 8 | tula
# Processing Record 10 of Set 8 | igarka
# Processing Record 11 of Set 8 | araguaina
# Processing Record 12 of Set 8 | hof
# Processing Record 13 of Set 8 | san vicente
# Processing Record 14 of Set 8 | lichuan
# Processing Record 15 of Set 8 | natal
# Processing Record 16 of Set 8 | basco
# Processing Record 17 of Set 8 | avallon
# Processing Record 18 of Set 8 | sebezh
# Processing Record 19 of Set 8 | yulara
# Processing Record 20 of Set 8 | astoria
# Processing Record 21 of Set 8 | colotlan
# Processing Record 22 of Set 8 | betsiamites
# Processing Record 23 of Set 8 | ranong
# Processing Record 24 of Set 8 | santa marta
# Processing Record 25 of Set 8 | antofagasta
# Processing Record 26 of Set 8 | dukat
# Processing Record 27 of Set 8 | rapid valley
# Processing Record 28 of Set 8 | nishihara
# Processing Record 29 of Set 8 | ulladulla
# Processing Record 30 of Set 8 | guanica
# Processing Record 31 of Set 8 | kingaroy
# Processing Record 32 of Set 8 | acari
# Processing Record 33 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 8 | chicama
# Processing Record 35 of Set 8 | niny
# Processing Record 36 of Set 8 | pouebo
# Processing Record 37 of Set 8 | fougeres
# Processing Record 38 of Set 8 | enfield
# Processing Record 39 of Set 8 | murgab
# Processing Record 40 of Set 8 | ahipara
# Processing Record 41 of Set 8 | paita
# Processing Record 42 of Set 8 | kupang
# Processing Record 43 of Set 8 | clarence town
# Processing Record 44 of Set 8 | manadhoo
# Processing Record 45 of Set 8 | los andes
# Processing Record 46 of Set 8 | kathu
# Processing Record 47 of Set 8 | ilulissat
# Processing Record 48 of Set 8 | fort walton beach
# Processing Record 49 of Set 8 | semikarakorsk
# Processing Record 50 of Set 8 | chibombo
# Processing Record 1 of Set 9 | pangnirtung
# Processing Record 2 of Set 9 | guatire
# Processing Record 3 of Set 9 | moss vale
# Processing Record 4 of Set 9 | labytnangi
# Processing Record 5 of Set 9 | kilindoni
# Processing Record 6 of Set 9 | yar-sale
# Processing Record 7 of Set 9 | golfito
# Processing Record 8 of Set 9 | laguna
# Processing Record 9 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 10 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 9 | mackay
# Processing Record 12 of Set 9 | serta
# Processing Record 13 of Set 9 | christchurch
# Processing Record 14 of Set 9 | pitimbu
# Processing Record 15 of Set 9 | ahuimanu
# Processing Record 16 of Set 9 | nha trang
# Processing Record 17 of Set 9 | prado
# Processing Record 18 of Set 9 | gimli
# Processing Record 19 of Set 9 | harper
# Processing Record 20 of Set 9 | sao desiderio
# Processing Record 21 of Set 9 | nantucket
# Processing Record 22 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 9 | alta floresta
# Processing Record 24 of Set 9 | san patricio
# Processing Record 25 of Set 9 | gouyave
# Processing Record 26 of Set 9 | ulaangom
# Processing Record 27 of Set 9 | najran
# Processing Record 28 of Set 9 | bilibino
# Processing Record 29 of Set 9 | east london
# Processing Record 30 of Set 9 | poum
# Processing Record 31 of Set 9 | terrace
# Processing Record 32 of Set 9 | monrovia
# Processing Record 33 of Set 9 | nyuksenitsa
# Processing Record 34 of Set 9 | baykit
# Processing Record 35 of Set 9 | makakilo city
# Processing Record 36 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 37 of Set 9 | berlevag
# Processing Record 38 of Set 9 | blagodatnoye
# Processing Record 39 of Set 9 | luohe
# Processing Record 40 of Set 9 | mnogovershinnyy
# Processing Record 41 of Set 9 | gisborne
# Processing Record 42 of Set 9 | sampit
# Processing Record 43 of Set 9 | hirado
# Processing Record 44 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 45 of Set 9 | bonfim
# Processing Record 46 of Set 9 | sakakah
# Processing Record 47 of Set 9 | kemijarvi
# Processing Record 48 of Set 9 | alice springs
# Processing Record 49 of Set 9 | kalmunai
# Processing Record 50 of Set 9 | pocoes
# Processing Record 1 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 10 | atchison
# Processing Record 3 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 4 of Set 10 | honningsvag
# Processing Record 5 of Set 10 | narsaq
# Processing Record 6 of Set 10 | turinsk
# Processing Record 7 of Set 10 | pietarsaari
# Processing Record 8 of Set 10 | akdepe
# Processing Record 9 of Set 10 | kamskiye polyany
# Processing Record 10 of Set 10 | astipalaia
# City not found. Skipping...
# Processing Record 11 of Set 10 | foshan
# Processing Record 12 of Set 10 | teguldet
# Processing Record 13 of Set 10 | muravlenko
# Processing Record 14 of Set 10 | nemuro
# Processing Record 15 of Set 10 | marzuq
# Processing Record 16 of Set 10 | minas
# Processing Record 17 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 18 of Set 10 | poya
# Processing Record 19 of Set 10 | talnakh
# Processing Record 20 of Set 10 | puerto escondido
# Processing Record 21 of Set 10 | prince rupert
# Processing Record 22 of Set 10 | a
# City not found. Skipping...
# Processing Record 23 of Set 10 | beloha
# Processing Record 24 of Set 10 | xuanzhou
# Processing Record 25 of Set 10 | huacho
# Processing Record 26 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 27 of Set 10 | gediz
# Processing Record 28 of Set 10 | panzhihua
# Processing Record 29 of Set 10 | selma
# Processing Record 30 of Set 10 | kankon
# Processing Record 31 of Set 10 | barabash
# Processing Record 32 of Set 10 | aklavik
# Processing Record 33 of Set 10 | bang saphan
# Processing Record 34 of Set 10 | knysna
# Processing Record 35 of Set 10 | matara
# Processing Record 36 of Set 10 | chamba
# Processing Record 37 of Set 10 | bardiyah
# Processing Record 38 of Set 10 | magaria
# Processing Record 39 of Set 10 | beyneu
# Processing Record 40 of Set 10 | sholokhove
# Processing Record 41 of Set 10 | dzerzhinskoye
# Processing Record 42 of Set 10 | morshyn
# Processing Record 43 of Set 10 | fairbanks
# Processing Record 44 of Set 10 | carauari
# Processing Record 45 of Set 10 | vanavara
# Processing Record 46 of Set 10 | todos santos
# Processing Record 47 of Set 10 | prabumulih
# Processing Record 48 of Set 10 | sioux lookout
# Processing Record 49 of Set 10 | miramar
# Processing Record 50 of Set 10 | chake chake
# Processing Record 1 of Set 11 | fonte boa
# Processing Record 2 of Set 11 | nara
# Processing Record 3 of Set 11 | yazd
# Processing Record 4 of Set 11 | morant bay
# Processing Record 5 of Set 11 | imeni vorovskogo
# Processing Record 6 of Set 11 | jaciara
# Processing Record 7 of Set 11 | terney
# Processing Record 8 of Set 11 | ormond beach
# Processing Record 9 of Set 11 | ikongo
# Processing Record 10 of Set 11 | darhan
# Processing Record 11 of Set 11 | ridgecrest
# Processing Record 12 of Set 11 | abiy adi
# City not found. Skipping...
# Processing Record 13 of Set 11 | bonavista
# Processing Record 14 of Set 11 | gusau
# Processing Record 15 of Set 11 | fort nelson
# Processing Record 16 of Set 11 | yate
# Processing Record 17 of Set 11 | shkotovo-26
# City not found. Skipping...
# Processing Record 18 of Set 11 | vila velha
# Processing Record 19 of Set 11 | bristol
# Processing Record 20 of Set 11 | dudinka
# Processing Record 21 of Set 11 | olafsvik
# Processing Record 22 of Set 11 | innisfail
# Processing Record 23 of Set 11 | puerto rico
# Processing Record 24 of Set 11 | khon kaen
# Processing Record 25 of Set 11 | sao carlos
# Processing Record 26 of Set 11 | flin flon
# Processing Record 27 of Set 11 | imbituba
# Processing Record 28 of Set 11 | san cristobal
# Processing Record 29 of Set 11 | totness
# Processing Record 30 of Set 11 | yeppoon
# Processing Record 31 of Set 11 | coahuayana
# Processing Record 32 of Set 11 | snyder
# Processing Record 33 of Set 11 | verkhniy uslon
# Processing Record 34 of Set 11 | nouadhibou
# Processing Record 35 of Set 11 | moosomin
# Processing Record 36 of Set 11 | parras
# City not found. Skipping...
# Processing Record 37 of Set 11 | pangkalanbuun
# Processing Record 38 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 11 | mahibadhoo
# Processing Record 40 of Set 11 | sosnovka
# Processing Record 41 of Set 11 | ambanja
# Processing Record 42 of Set 11 | waingapu
# Processing Record 43 of Set 11 | tiznit
# Processing Record 44 of Set 11 | termiz
# Processing Record 45 of Set 11 | haines junction
# Processing Record 46 of Set 11 | bartica
# Processing Record 47 of Set 11 | terra santa
# Processing Record 48 of Set 11 | russell
# Processing Record 49 of Set 11 | san fernando
# Processing Record 50 of Set 11 | praia
# Processing Record 1 of Set 12 | hobyo
# Processing Record 2 of Set 12 | boende
# Processing Record 3 of Set 12 | biak
# Processing Record 4 of Set 12 | dwarka
# Processing Record 5 of Set 12 | enterprise
# Processing Record 6 of Set 12 | kurilsk
# Processing Record 7 of Set 12 | turukhansk
# Processing Record 8 of Set 12 | pakxan
# Processing Record 9 of Set 12 | presidencia roque saenz pena
# Processing Record 10 of Set 12 | zeya
# Processing Record 11 of Set 12 | carupano
# Processing Record 12 of Set 12 | mocuba
# Processing Record 13 of Set 12 | adrar
# Processing Record 14 of Set 12 | nabire
# Processing Record 15 of Set 12 | talcahuano
# Processing Record 16 of Set 12 | neyshabur
# Processing Record 17 of Set 12 | bay roberts
# Processing Record 18 of Set 12 | bodden town
# Processing Record 19 of Set 12 | nybro
# Processing Record 20 of Set 12 | mapiripan
# Processing Record 21 of Set 12 | jiguani
# Processing Record 22 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 12 | keshod
# Processing Record 24 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 12 | san luis
# Processing Record 26 of Set 12 | morehead
# Processing Record 27 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 28 of Set 12 | faro
# Processing Record 29 of Set 12 | lagunas
# Processing Record 30 of Set 12 | ambunti
# Processing Record 31 of Set 12 | astana
# Processing Record 32 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 12 | cheney
# Processing Record 34 of Set 12 | aswan
# Processing Record 35 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 36 of Set 12 | vestmannaeyjar
# Processing Record 37 of Set 12 | hamilton
# Processing Record 38 of Set 12 | tambura
# Processing Record 39 of Set 12 | plaster rock
# Processing Record 40 of Set 12 | shablykino
# Processing Record 41 of Set 12 | mahajanga
# Processing Record 42 of Set 12 | manaus
# Processing Record 43 of Set 12 | srivardhan
# Processing Record 44 of Set 12 | sao filipe
# Processing Record 45 of Set 12 | aranos
# Processing Record 46 of Set 12 | la palma
# Processing Record 47 of Set 12 | ravar
# Processing Record 48 of Set 12 | dunedin
# Processing Record 49 of Set 12 | majene
# Processing Record 50 of Set 12 | te anau
# Processing Record 1 of Set 13 | mandan
# Processing Record 2 of Set 13 | khandyga
# Processing Record 3 of Set 13 | adamas
# Processing Record 4 of Set 13 | salinopolis
# Processing Record 5 of Set 13 | siocon
# Processing Record 6 of Set 13 | palana
# Processing Record 7 of Set 13 | sahiwal
# Processing Record 8 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 13 | san joaquin
# Processing Record 10 of Set 13 | rocha
# Processing Record 11 of Set 13 | dhenkanal
# Processing Record 12 of Set 13 | bahia honda
# Processing Record 13 of Set 13 | kloulklubed
# Processing Record 14 of Set 13 | mazagao
# Processing Record 15 of Set 13 | sistranda
# Processing Record 16 of Set 13 | raahe
# Processing Record 17 of Set 13 | sungurlu
# Processing Record 18 of Set 13 | lakatoro
# Processing Record 19 of Set 13 | careiro da varzea
# Processing Record 20 of Set 13 | clearwater
# Processing Record 21 of Set 13 | snezhnogorsk
# Processing Record 22 of Set 13 | kitimat
# Processing Record 23 of Set 13 | puerto madryn
# Processing Record 24 of Set 13 | shanghai
# Processing Record 25 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 13 | grindavik
# Processing Record 27 of Set 13 | cockburn town
# Processing Record 28 of Set 13 | omboue
# Processing Record 29 of Set 13 | holstebro
# Processing Record 30 of Set 13 | yelabuga
# Processing Record 31 of Set 13 | zhanaozen
# Processing Record 32 of Set 13 | kirakira
# Processing Record 33 of Set 13 | luderitz
# Processing Record 34 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 35 of Set 13 | palmares do sul
# Processing Record 36 of Set 13 | brigantine
# Processing Record 37 of Set 13 | kamsack
# Processing Record 38 of Set 13 | amudat
# Processing Record 39 of Set 13 | micheweni
# Processing Record 40 of Set 13 | huambo
# Processing Record 41 of Set 13 | progreso
# Processing Record 42 of Set 13 | naze
# Processing Record 43 of Set 13 | tura
# Processing Record 44 of Set 13 | whitefish
# Processing Record 45 of Set 13 | pahrump
# Processing Record 46 of Set 13 | punto fijo
# Processing Record 47 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 48 of Set 13 | kholtoson
# Processing Record 49 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 13 | kalininsk
# Processing Record 1 of Set 14 | almaznyy
# Processing Record 2 of Set 14 | svetlaya
# Processing Record 3 of Set 14 | bom jesus
# Processing Record 4 of Set 14 | sur
# Processing Record 5 of Set 14 | goderich
# Processing Record 6 of Set 14 | estelle
# Processing Record 7 of Set 14 | teluk nibung
# Processing Record 8 of Set 14 | alto vera
# City not found. Skipping...
# Processing Record 9 of Set 14 | parsabad
# Processing Record 10 of Set 14 | ambon
# Processing Record 11 of Set 14 | rio grande
# Processing Record 12 of Set 14 | pozoblanco
# Processing Record 13 of Set 14 | miastko
# Processing Record 14 of Set 14 | lucea
# Processing Record 15 of Set 14 | neuquen
# Processing Record 16 of Set 14 | kipini
# Processing Record 17 of Set 14 | azovo
# Processing Record 18 of Set 14 | nuevo progreso
# Processing Record 19 of Set 14 | tessalit
# Processing Record 20 of Set 14 | port blair
# Processing Record 21 of Set 14 | avera
# Processing Record 22 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 23 of Set 14 | hinton
# Processing Record 24 of Set 14 | morondava
# Processing Record 25 of Set 14 | maldonado
# Processing Record 26 of Set 14 | panjakent
# Processing Record 27 of Set 14 | rojhan
# Processing Record 28 of Set 14 | akyab
# Processing Record 29 of Set 14 | troyes
# Processing Record 30 of Set 14 | mezen
# Processing Record 31 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 32 of Set 14 | port macquarie
# Processing Record 33 of Set 14 | corrente
# Processing Record 34 of Set 14 | marawi
# Processing Record 35 of Set 14 | amapa
# Processing Record 36 of Set 14 | coos bay
# Processing Record 37 of Set 14 | umm lajj
# Processing Record 38 of Set 14 | lamu
# Processing Record 39 of Set 14 | baghdad
# Processing Record 40 of Set 14 | chinsali
# Processing Record 41 of Set 14 | latung
# Processing Record 42 of Set 14 | davila
# Processing Record 43 of Set 14 | south river
# Processing Record 44 of Set 14 | filingue
# Processing Record 45 of Set 14 | tutoia
# Processing Record 46 of Set 14 | shigony
# Processing Record 47 of Set 14 | mastic beach
# Processing Record 48 of Set 14 | kijang
# Processing Record 49 of Set 14 | selkirk
# Processing Record 50 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 15 | necochea
# Processing Record 2 of Set 15 | pemba
# Processing Record 3 of Set 15 | clinton
# Processing Record 4 of Set 15 | solnechnyy
# Processing Record 5 of Set 15 | palmer
# Processing Record 6 of Set 15 | snasa
# Processing Record 7 of Set 15 | vostok
# Processing Record 8 of Set 15 | takoradi
# Processing Record 9 of Set 15 | diffa
# Processing Record 10 of Set 15 | port-gentil
# Processing Record 11 of Set 15 | brainerd
# Processing Record 12 of Set 15 | luba
# Processing Record 13 of Set 15 | luau
# Processing Record 14 of Set 15 | fairview
# Processing Record 15 of Set 15 | kavaratti
# Processing Record 16 of Set 15 | berdigestyakh
# Processing Record 17 of Set 15 | severnyy
# Processing Record 18 of Set 15 | belle fourche
# Processing Record 19 of Set 15 | mount gambier
# Processing Record 20 of Set 15 | deputatskiy
# Processing Record 21 of Set 15 | balakhta
# Processing Record 22 of Set 15 | quelimane
# Processing Record 23 of Set 15 | san antonio
# Processing Record 24 of Set 15 | gayny
# Processing Record 25 of Set 15 | seymchan
# Processing Record 26 of Set 15 | ossora
# Processing Record 27 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 28 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 15 | qui nhon
# Processing Record 30 of Set 15 | charters towers
# Processing Record 31 of Set 15 | mahon
# Processing Record 32 of Set 15 | umm kaddadah
# Processing Record 33 of Set 15 | alofi
# Processing Record 34 of Set 15 | esso
# Processing Record 35 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 15 | blagoyevo
# Processing Record 37 of Set 15 | road town
# Processing Record 38 of Set 15 | ugoofaaru
# Processing Record 39 of Set 15 | bilma
# Processing Record 40 of Set 15 | mamou
# Processing Record 41 of Set 15 | iwanai
# Processing Record 42 of Set 15 | kieta
# Processing Record 43 of Set 15 | sharkan
# Processing Record 44 of Set 15 | tias
# Processing Record 45 of Set 15 | blacksburg
# Processing Record 46 of Set 15 | mattru
# Processing Record 47 of Set 15 | port hueneme
# Processing Record 48 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 49 of Set 15 | chifeng
# Processing Record 50 of Set 15 | mwingi
# Processing Record 1 of Set 16 | zhigansk
# Processing Record 2 of Set 16 | klaksvik
# Processing Record 3 of Set 16 | priargunsk
# Processing Record 4 of Set 16 | kysyl-syr
# Processing Record 5 of Set 16 | carballo
# Processing Record 6 of Set 16 | sovetskiy
# Processing Record 7 of Set 16 | san juan
# Processing Record 8 of Set 16 | austin
# Processing Record 9 of Set 16 | erzurum
# Processing Record 10 of Set 16 | shamary
# Processing Record 11 of Set 16 | lincoln
# Processing Record 12 of Set 16 | eureka
# Processing Record 13 of Set 16 | sunnyside
# Processing Record 14 of Set 16 | kovur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Hasaki  35.7333  140.8333     64.80        87         100
# 1             Artyom  40.4723   50.3330     71.74        77           1
# 2                Vao -22.6667  167.4833     73.49        71          17
# 3             Dikson  73.5069   80.5464     30.87        91         100
# 4           Hermanus -34.4187   19.2345     61.99        47          10
# 5             Maridi   4.9158   29.4742     66.15        86           6
# 6    Arraial Do Cabo -22.9661  -42.0278     68.72        68           2
# 7           Victoria  22.2855  114.1577     89.65        82         100
# 8           Frasinet  44.3167   26.8000     65.68        89          31
# 9  Riviere-Au-Renard  48.9957  -64.3971     43.09        75          63
#
#    Wind Speed Country Current Description                 Date
# 0       21.05      JP          light rain  2022-06-06 03:16:06
# 1        9.53      AZ           clear sky  2022-06-06 03:16:06
# 2        7.76      NC          few clouds  2022-06-06 03:16:07
# 3       12.84      RU     overcast clouds  2022-06-06 03:16:07
# 4        7.54      ZA           clear sky  2022-06-06 03:16:07
# 5        4.34      SS           clear sky  2022-06-06 03:16:08
# 6       17.63      BR           clear sky  2022-06-06 03:16:08
# 7       11.99      HK     overcast clouds  2022-06-06 03:13:38
# 8       12.82      RO    scattered clouds  2022-06-06 03:16:08
# 9        3.20      CA       broken clouds  2022-06-06 03:16:09

# %%
#reorder columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hasaki      JP  35.7333  140.8333     64.80        87         100
# 1       Artyom      AZ  40.4723   50.3330     71.74        77           1
# 2          Vao      NC -22.6667  167.4833     73.49        71          17
# 3       Dikson      RU  73.5069   80.5464     30.87        91         100
# 4     Hermanus      ZA -34.4187   19.2345     61.99        47          10
# ..         ...     ...      ...       ...       ...       ...         ...
# 694    Shamary      RU  57.3434   58.2199     56.98        74         100
# 695    Lincoln      US  40.8000  -96.6670     69.71        94          40
# 696     Eureka      US  40.8021 -124.1637     60.67        87          84
# 697  Sunnyside      US  46.3237 -120.0087     67.84        52          40
# 698      Kovur      IN  14.4833   79.9833     93.42        42          99
#
#      Wind Speed Current Description
# 0         21.05          light rain
# 1          9.53           clear sky
# 2          7.76          few clouds
# 3         12.84     overcast clouds
# 4          7.54           clear sky
# ..          ...                 ...
# 694        6.69     overcast clouds
# 695        1.01    scattered clouds
# 696        3.00       broken clouds
# 697       12.66    scattered clouds
# 698       14.05     overcast clouds
#
# [699 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "/Users/christiannaweisert/Desktop/Class_Folder/6-World_Weather_Analysis/weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
